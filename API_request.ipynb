# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import sys
sys.path.append("../")
from ruta_a_mi_archivo import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dda37959aeb4> in <module>
#       1 import sys
#       2 sys.path.append("../")
# ----> 3 from src.apifunctions import *
#
# ModuleNotFoundError: No module named 'src.apifunctions'
